# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import torch
import random
import time
import os
from collections import defaultdict

# Import environment and agents
from Othello.Env.env import OthelloEnv, BLACK, WHITE, EMPTY, BOARD_SIZE
from Othello.Agents.random import RandomAgent
from Othello.Agents.mcts import MCTSAgent
from Othello.Agents.dqn import DQNAgent
from Othello.Utils.evaluate_agent import evaluate_agent
from Othello.Utils.visualize_game import visualize_game

# Set random seeds for reproducibility
np.random.seed(42)
random.seed(42)
torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(42)

# Create models directory if it doesn't exist
os.makedirs("models", exist_ok=True)

# %%
# Initialize the environment
env = OthelloEnv()

# Initialize Random Agent
random_agent = RandomAgent()

# Initialize MCTS Agent with different simulation counts
mcts_agent_fast = MCTSAgent(num_simulations=50)
mcts_agent = MCTSAgent(num_simulations=100)
mcts_agent_deep = MCTSAgent(num_simulations=200)

# Initialize DQN Agent
dqn_agent = DQNAgent(
    state_shape=(BOARD_SIZE, BOARD_SIZE),
    action_size=BOARD_SIZE * BOARD_SIZE,
    memory_size=10000,
    gamma=0.95,
    epsilon=1.0,
    epsilon_min=0.01,
    epsilon_decay=0.995,
    learning_rate=0.001,
    batch_size=64,
    update_target_freq=10,
    reward_scale=0.05,
)

print(f"Device used for DQN: {dqn_agent.device}")
# Out:
# Device used for DQN: cuda

# %%
# Define opponents and their probabilities
opponents = {
    'self': dqn_agent,  # Self-play
    'random': random_agent,
    'mcts_fast': mcts_agent_fast
}

# Define opponent probabilities (75% self-play, 15% MCTS, 10% random)
opponent_probs = {
    'self': 0.75,
    'random': 0.10,
    'mcts_fast': 0.15
}

# Number of training episodes
num_episodes = 1500

# Train the DQN agent
print(f"Training DQN agent for {num_episodes} episodes...")
rewards, losses = dqn_agent.train(env, num_episodes=num_episodes, 
                                 opponents=opponents, opponent_probs=opponent_probs)

# Save the trained model
dqn_agent.save("Othello/Models/dqn_trained")
print("DQN agent training completed and model saved.")
# Out:
# Training DQN agent for 1500 episodes...
# Episode 10/1500, Opponents: self: 10, random: 0, mcts_fast: 0, Reward: 268.00, Loss: 0.0092, Epsilon: 0.3095
# Episode 20/1500, Opponents: self: 9, random: 0, mcts_fast: 1, Reward: 188.00, Loss: 0.0134, Epsilon: 0.0688
# Episode 30/1500, Opponents: self: 10, random: 0, mcts_fast: 0, Reward: 24.00, Loss: 0.0189, Epsilon: 0.0153
# Episode 40/1500, Opponents: self: 7, random: 1, mcts_fast: 2, Reward: 510.00, Loss: 0.0582, Epsilon: 0.0100
# Episode 50/1500, Opponents: self: 9, random: 0, mcts_fast: 1, Reward: 82.00, Loss: 0.1529, Epsilon: 0.0100
# Episode 60/1500, Opponents: self: 9, random: 0, mcts_fast: 1, Reward: 392.00, Loss: 0.0722, Epsilon: 0.0100
# Episode 70/1500, Opponents: self: 10, random: 0, mcts_fast: 0, Reward: 368.00, Loss: 0.0711, Epsilon: 0.0100
# Episode 80/1500, Opponents: self: 8, random: 0, mcts_fast: 2, Reward: 336.00, Loss: 0.1114, Epsilon: 0.0100
# Episode 90/1500, Opponents: self: 10, random: 0, mcts_fast: 0, Reward: 314.00, Loss: 0.0939, Epsilon: 0.0100
# Episode 100/1500, Opponents: self: 10, random: 0, mcts_fast: 0, Reward: 246.00, Loss: 0.0957, Epsilon: 0.0100
# Episode 110/1500, Opponents: self: 10, random: 0, mcts_fast: 0, Reward: 280.00, Loss: 0.1432, Epsilon: 0.0100
# Episode 120/1500, Opponents: self: 9, random: 0, mcts_fast: 1, Reward: 218.00, Loss: 0.1259, Epsilon: 0.0100
# Episode 130/1500, Opponents: self: 9, random: 0, mcts_fast: 1, Reward: 656.00, Loss: 0.0914, Epsilon: 0.0100
# Episode 140/1500, Opponents: self: 9, random: 0, mcts_fast: 1, Reward: -123.00, Loss: 0.1064, Epsilon: 0.0100
# Episode 150/1500, Opponents: self: 10, random: 0, mcts_fast: 0, Reward: 22.00, Loss: 0.1223, Epsilon: 0.0100
# Episode 160/1500, Opponents: self: 10, random: 0, mcts_fast: 0, Reward: 176.00, Loss: 0.1428, Epsilon: 0.0100
# Episode 170/1500, Opponents: self: 10, random: 0, mcts_fast: 0, Reward: 198.00, Loss: 0.1327, Epsilon: 0.0100
# Episode 180/1500, Opponents: self: 10, random: 0, mcts_fast: 0, Reward: 380.00, Loss: 0.1329, Epsilon: 0.0100
# Episode 190/1500, Opponents: self: 8, random: 2, mcts_fast: 0, Reward: 22.00, Loss: 0.1231, Epsilon: 0.0100
# Episode 200/1500, Opponents: self: 7, random: 0, mcts_fast: 3, Reward: 528.00, Loss: 0.1195, Epsilon: 0.0100
# Episode 210/1500, Opponents: self: 9, random: 1, mcts_fast: 0, Reward: 434.00, Loss: 0.1289, Epsilon: 0.0100
# Episode 220/1500, Opponents: self: 10, random: 0, mcts_fast: 0, Reward: 472.00, Loss: 0.1298, Epsilon: 0.0100
# Episode 230/1500, Opponents: self: 9, random: 1, mcts_fast: 0, Reward: 378.00, Loss: 0.1318, Epsilon: 0.0100
# Episode 240/1500, Opponents: self: 9, random: 1, mcts_fast: 0, Reward: 222.00, Loss: 0.1662, Epsilon: 0.0100
# Episode 250/1500, Opponents: self: 9, random: 0, mcts_fast: 1, Reward: 292.00, Loss: 0.1465, Epsilon: 0.0100
# Episode 260/1500, Opponents: self: 9, random: 0, mcts_fast: 1, Reward: 260.00, Loss: 0.1336, Epsilon: 0.0100
# Episode 270/1500, Opponents: self: 9, random: 0, mcts_fast: 1, Reward: 282.00, Loss: 0.1170, Epsilon: 0.0100
# Episode 280/1500, Opponents: self: 9, random: 0, mcts_fast: 1, Reward: 208.00, Loss: 0.1307, Epsilon: 0.0100
# Episode 290/1500, Opponents: self: 10, random: 0, mcts_fast: 0, Reward: 562.00, Loss: 0.1160, Epsilon: 0.0100
# Episode 300/1500, Opponents: self: 8, random: 1, mcts_fast: 1, Reward: -38.00, Loss: 0.1562, Epsilon: 0.0100
# Episode 310/1500, Opponents: self: 10, random: 0, mcts_fast: 0, Reward: 428.00, Loss: 0.1857, Epsilon: 0.0100
# Episode 320/1500, Opponents: self: 9, random: 0, mcts_fast: 1, Reward: 390.00, Loss: 0.1522, Epsilon: 0.0100
# Episode 330/1500, Opponents: self: 9, random: 1, mcts_fast: 0, Reward: 524.00, Loss: 0.1165, Epsilon: 0.0100
# Episode 340/1500, Opponents: self: 8, random: 2, mcts_fast: 0, Reward: 272.00, Loss: 0.1254, Epsilon: 0.0100
# Episode 350/1500, Opponents: self: 10, random: 0, mcts_fast: 0, Reward: 396.00, Loss: 0.1292, Epsilon: 0.0100
# Episode 360/1500, Opponents: self: 6, random: 2, mcts_fast: 2, Reward: 296.00, Loss: 0.1521, Epsilon: 0.0100
# Episode 370/1500, Opponents: self: 8, random: 0, mcts_fast: 2, Reward: 294.00, Loss: 0.1195, Epsilon: 0.0100
# Episode 380/1500, Opponents: self: 9, random: 0, mcts_fast: 1, Reward: 280.00, Loss: 0.1632, Epsilon: 0.0100
# Episode 390/1500, Opponents: self: 10, random: 0, mcts_fast: 0, Reward: 181.00, Loss: 0.1975, Epsilon: 0.0100
# Episode 400/1500, Opponents: self: 9, random: 1, mcts_fast: 0, Reward: 144.00, Loss: 0.1889, Epsilon: 0.0100
# Episode 410/1500, Opponents: self: 9, random: 0, mcts_fast: 1, Reward: 320.00, Loss: 0.1399, Epsilon: 0.0100
# Episode 420/1500, Opponents: self: 8, random: 1, mcts_fast: 1, Reward: 286.00, Loss: 0.1263, Epsilon: 0.0100
# Episode 430/1500, Opponents: self: 8, random: 1, mcts_fast: 1, Reward: 388.00, Loss: 0.1189, Epsilon: 0.0100
# Episode 440/1500, Opponents: self: 6, random: 3, mcts_fast: 1, Reward: 268.00, Loss: 0.1298, Epsilon: 0.0100
# Episode 450/1500, Opponents: self: 10, random: 0, mcts_fast: 0, Reward: 10.00, Loss: 0.1377, Epsilon: 0.0100
# Episode 460/1500, Opponents: self: 8, random: 2, mcts_fast: 0, Reward: 278.00, Loss: 0.1625, Epsilon: 0.0100
# Episode 470/1500, Opponents: self: 6, random: 0, mcts_fast: 4, Reward: 242.00, Loss: 0.1601, Epsilon: 0.0100
# Episode 480/1500, Opponents: self: 9, random: 0, mcts_fast: 1, Reward: 498.00, Loss: 0.1370, Epsilon: 0.0100
# Episode 490/1500, Opponents: self: 7, random: 0, mcts_fast: 3, Reward: 76.00, Loss: 0.1250, Epsilon: 0.0100
# Episode 500/1500, Opponents: self: 10, random: 0, mcts_fast: 0, Reward: 466.00, Loss: 0.1119, Epsilon: 0.0100
# Episode 510/1500, Opponents: self: 9, random: 1, mcts_fast: 0, Reward: 220.00, Loss: 0.1283, Epsilon: 0.0100
# Episode 520/1500, Opponents: self: 8, random: 1, mcts_fast: 1, Reward: 236.00, Loss: 0.1397, Epsilon: 0.0100
# Episode 530/1500, Opponents: self: 9, random: 1, mcts_fast: 0, Reward: 15.00, Loss: 0.2002, Epsilon: 0.0100
# Episode 540/1500, Opponents: self: 6, random: 1, mcts_fast: 3, Reward: 673.00, Loss: 0.1538, Epsilon: 0.0100
# Episode 550/1500, Opponents: self: 9, random: 0, mcts_fast: 1, Reward: 344.00, Loss: 0.1432, Epsilon: 0.0100
# Episode 560/1500, Opponents: self: 8, random: 1, mcts_fast: 1, Reward: 48.00, Loss: 0.1464, Epsilon: 0.0100
# Episode 570/1500, Opponents: self: 10, random: 0, mcts_fast: 0, Reward: 170.00, Loss: 0.1115, Epsilon: 0.0100
# Episode 580/1500, Opponents: self: 6, random: 2, mcts_fast: 2, Reward: 102.00, Loss: 0.1535, Epsilon: 0.0100
# Episode 590/1500, Opponents: self: 9, random: 1, mcts_fast: 0, Reward: 14.00, Loss: 0.1292, Epsilon: 0.0100
# Episode 600/1500, Opponents: self: 8, random: 2, mcts_fast: 0, Reward: 248.00, Loss: 0.1100, Epsilon: 0.0100
# Episode 610/1500, Opponents: self: 9, random: 0, mcts_fast: 1, Reward: 184.00, Loss: 0.1036, Epsilon: 0.0100
# Episode 620/1500, Opponents: self: 10, random: 0, mcts_fast: 0, Reward: 264.00, Loss: 0.1447, Epsilon: 0.0100
# Episode 630/1500, Opponents: self: 7, random: 1, mcts_fast: 2, Reward: 452.00, Loss: 0.1052, Epsilon: 0.0100
# Episode 640/1500, Opponents: self: 9, random: 1, mcts_fast: 0, Reward: 630.00, Loss: 0.1138, Epsilon: 0.0100
# Episode 650/1500, Opponents: self: 10, random: 0, mcts_fast: 0, Reward: 472.00, Loss: 0.1508, Epsilon: 0.0100
# Episode 660/1500, Opponents: self: 7, random: 2, mcts_fast: 1, Reward: 177.00, Loss: 0.1223, Epsilon: 0.0100
# Episode 670/1500, Opponents: self: 7, random: 2, mcts_fast: 1, Reward: 319.00, Loss: 0.1360, Epsilon: 0.0100
# Episode 680/1500, Opponents: self: 5, random: 0, mcts_fast: 5, Reward: 343.00, Loss: 0.1117, Epsilon: 0.0100
# Episode 690/1500, Opponents: self: 9, random: 1, mcts_fast: 0, Reward: 26.00, Loss: 0.1033, Epsilon: 0.0100
# Episode 700/1500, Opponents: self: 7, random: 1, mcts_fast: 2, Reward: 206.00, Loss: 0.1044, Epsilon: 0.0100
# Episode 710/1500, Opponents: self: 9, random: 0, mcts_fast: 1, Reward: 450.00, Loss: 0.1065, Epsilon: 0.0100
# Episode 720/1500, Opponents: self: 6, random: 3, mcts_fast: 1, Reward: 320.00, Loss: 0.1252, Epsilon: 0.0100
# Episode 730/1500, Opponents: self: 8, random: 1, mcts_fast: 1, Reward: -14.00, Loss: 0.1291, Epsilon: 0.0100
# Episode 740/1500, Opponents: self: 8, random: 0, mcts_fast: 2, Reward: 43.00, Loss: 0.0999, Epsilon: 0.0100
# Episode 750/1500, Opponents: self: 9, random: 1, mcts_fast: 0, Reward: 438.00, Loss: 0.1100, Epsilon: 0.0100
# Episode 760/1500, Opponents: self: 6, random: 4, mcts_fast: 0, Reward: 46.00, Loss: 0.1277, Epsilon: 0.0100
# Episode 770/1500, Opponents: self: 8, random: 1, mcts_fast: 1, Reward: 284.00, Loss: 0.1131, Epsilon: 0.0100
# Episode 780/1500, Opponents: self: 6, random: 1, mcts_fast: 3, Reward: -29.00, Loss: 0.0972, Epsilon: 0.0100
# Episode 790/1500, Opponents: self: 8, random: 1, mcts_fast: 1, Reward: 190.00, Loss: 0.0976, Epsilon: 0.0100
# Episode 800/1500, Opponents: self: 6, random: 0, mcts_fast: 4, Reward: 198.00, Loss: 0.0769, Epsilon: 0.0100
# Episode 810/1500, Opponents: self: 5, random: 2, mcts_fast: 3, Reward: 78.00, Loss: 0.0899, Epsilon: 0.0100
# Episode 820/1500, Opponents: self: 7, random: 1, mcts_fast: 2, Reward: 85.00, Loss: 0.0902, Epsilon: 0.0100
# Episode 830/1500, Opponents: self: 8, random: 0, mcts_fast: 2, Reward: 302.00, Loss: 0.0758, Epsilon: 0.0100
# Episode 840/1500, Opponents: self: 7, random: 1, mcts_fast: 2, Reward: 436.00, Loss: 0.0967, Epsilon: 0.0100
# Episode 850/1500, Opponents: self: 8, random: 0, mcts_fast: 2, Reward: -16.00, Loss: 0.0922, Epsilon: 0.0100
# Episode 860/1500, Opponents: self: 7, random: 0, mcts_fast: 3, Reward: 348.00, Loss: 0.0732, Epsilon: 0.0100
# Episode 870/1500, Opponents: self: 7, random: 2, mcts_fast: 1, Reward: 374.00, Loss: 0.0730, Epsilon: 0.0100
# Episode 880/1500, Opponents: self: 7, random: 0, mcts_fast: 3, Reward: 298.00, Loss: 0.0738, Epsilon: 0.0100
# Episode 890/1500, Opponents: self: 3, random: 3, mcts_fast: 4, Reward: 162.00, Loss: 0.0935, Epsilon: 0.0100
# Episode 900/1500, Opponents: self: 6, random: 0, mcts_fast: 4, Reward: -147.00, Loss: 0.0735, Epsilon: 0.0100
# Episode 910/1500, Opponents: self: 7, random: 0, mcts_fast: 3, Reward: -46.00, Loss: 0.0884, Epsilon: 0.0100
# Episode 920/1500, Opponents: self: 9, random: 0, mcts_fast: 1, Reward: -28.00, Loss: 0.0721, Epsilon: 0.0100
# Episode 930/1500, Opponents: self: 9, random: 1, mcts_fast: 0, Reward: 426.00, Loss: 0.0582, Epsilon: 0.0100
# Episode 940/1500, Opponents: self: 9, random: 0, mcts_fast: 1, Reward: 390.00, Loss: 0.0545, Epsilon: 0.0100
# Episode 950/1500, Opponents: self: 7, random: 1, mcts_fast: 2, Reward: 504.00, Loss: 0.0542, Epsilon: 0.0100
# Episode 960/1500, Opponents: self: 8, random: 1, mcts_fast: 1, Reward: 158.00, Loss: 0.0546, Epsilon: 0.0100
# Episode 970/1500, Opponents: self: 7, random: 3, mcts_fast: 0, Reward: -152.00, Loss: 0.0636, Epsilon: 0.0100
# Episode 980/1500, Opponents: self: 7, random: 1, mcts_fast: 2, Reward: 433.00, Loss: 0.0549, Epsilon: 0.0100
# Episode 990/1500, Opponents: self: 8, random: 0, mcts_fast: 2, Reward: 394.00, Loss: 0.0569, Epsilon: 0.0100
# Episode 1000/1500, Opponents: self: 9, random: 1, mcts_fast: 0, Reward: 181.00, Loss: 0.0741, Epsilon: 0.0100
# Episode 1010/1500, Opponents: self: 7, random: 1, mcts_fast: 2, Reward: -86.00, Loss: 0.0669, Epsilon: 0.0100
# Episode 1020/1500, Opponents: self: 9, random: 1, mcts_fast: 0, Reward: 284.00, Loss: 0.0591, Epsilon: 0.0100
# Episode 1030/1500, Opponents: self: 5, random: 3, mcts_fast: 2, Reward: -158.00, Loss: 0.0615, Epsilon: 0.0100
# Episode 1040/1500, Opponents: self: 7, random: 1, mcts_fast: 2, Reward: 28.00, Loss: 0.0591, Epsilon: 0.0100
# Episode 1050/1500, Opponents: self: 8, random: 0, mcts_fast: 2, Reward: -16.00, Loss: 0.0486, Epsilon: 0.0100
# Episode 1060/1500, Opponents: self: 7, random: 2, mcts_fast: 1, Reward: 692.00, Loss: 0.0508, Epsilon: 0.0100
# Episode 1070/1500, Opponents: self: 8, random: 0, mcts_fast: 2, Reward: 292.00, Loss: 0.0600, Epsilon: 0.0100
# Episode 1080/1500, Opponents: self: 6, random: 1, mcts_fast: 3, Reward: 50.00, Loss: 0.0484, Epsilon: 0.0100
# Episode 1090/1500, Opponents: self: 10, random: 0, mcts_fast: 0, Reward: 443.00, Loss: 0.0476, Epsilon: 0.0100
# Episode 1100/1500, Opponents: self: 9, random: 1, mcts_fast: 0, Reward: 554.00, Loss: 0.0528, Epsilon: 0.0100
# Episode 1110/1500, Opponents: self: 9, random: 0, mcts_fast: 1, Reward: 444.00, Loss: 0.0474, Epsilon: 0.0100
# Episode 1120/1500, Opponents: self: 9, random: 0, mcts_fast: 1, Reward: 229.00, Loss: 0.0473, Epsilon: 0.0100
# Episode 1130/1500, Opponents: self: 9, random: 0, mcts_fast: 1, Reward: 262.00, Loss: 0.0550, Epsilon: 0.0100
# Episode 1140/1500, Opponents: self: 6, random: 2, mcts_fast: 2, Reward: -250.00, Loss: 0.0674, Epsilon: 0.0100
# Episode 1150/1500, Opponents: self: 9, random: 0, mcts_fast: 1, Reward: 54.00, Loss: 0.0505, Epsilon: 0.0100
# Episode 1160/1500, Opponents: self: 8, random: 1, mcts_fast: 1, Reward: 436.00, Loss: 0.0439, Epsilon: 0.0100
# Episode 1170/1500, Opponents: self: 6, random: 3, mcts_fast: 1, Reward: 242.00, Loss: 0.0552, Epsilon: 0.0100
# Episode 1180/1500, Opponents: self: 9, random: 0, mcts_fast: 1, Reward: 242.00, Loss: 0.0547, Epsilon: 0.0100
# Episode 1190/1500, Opponents: self: 9, random: 0, mcts_fast: 1, Reward: 332.00, Loss: 0.0471, Epsilon: 0.0100
# Episode 1200/1500, Opponents: self: 7, random: 2, mcts_fast: 1, Reward: 262.00, Loss: 0.0471, Epsilon: 0.0100
# Episode 1210/1500, Opponents: self: 7, random: 1, mcts_fast: 2, Reward: 192.00, Loss: 0.0572, Epsilon: 0.0100
# Episode 1220/1500, Opponents: self: 7, random: 2, mcts_fast: 1, Reward: -40.00, Loss: 0.0558, Epsilon: 0.0100
# Episode 1230/1500, Opponents: self: 7, random: 3, mcts_fast: 0, Reward: 502.00, Loss: 0.0449, Epsilon: 0.0100
# Episode 1240/1500, Opponents: self: 7, random: 0, mcts_fast: 3, Reward: 360.00, Loss: 0.0520, Epsilon: 0.0100
# Episode 1250/1500, Opponents: self: 8, random: 1, mcts_fast: 1, Reward: 456.00, Loss: 0.0389, Epsilon: 0.0100
# Episode 1260/1500, Opponents: self: 6, random: 0, mcts_fast: 4, Reward: 94.00, Loss: 0.0475, Epsilon: 0.0100
# Episode 1270/1500, Opponents: self: 7, random: 1, mcts_fast: 2, Reward: 242.00, Loss: 0.0438, Epsilon: 0.0100
# Episode 1280/1500, Opponents: self: 7, random: 2, mcts_fast: 1, Reward: 538.00, Loss: 0.0400, Epsilon: 0.0100
# Episode 1290/1500, Opponents: self: 8, random: 2, mcts_fast: 0, Reward: 360.00, Loss: 0.0564, Epsilon: 0.0100
# Episode 1300/1500, Opponents: self: 8, random: 1, mcts_fast: 1, Reward: 186.00, Loss: 0.0461, Epsilon: 0.0100
# Episode 1310/1500, Opponents: self: 6, random: 2, mcts_fast: 2, Reward: 346.00, Loss: 0.0579, Epsilon: 0.0100
# Episode 1320/1500, Opponents: self: 7, random: 1, mcts_fast: 2, Reward: 372.00, Loss: 0.0406, Epsilon: 0.0100
# Episode 1330/1500, Opponents: self: 8, random: 1, mcts_fast: 1, Reward: 69.00, Loss: 0.0407, Epsilon: 0.0100
# Episode 1340/1500, Opponents: self: 6, random: 2, mcts_fast: 2, Reward: -40.00, Loss: 0.0355, Epsilon: 0.0100
# Episode 1350/1500, Opponents: self: 9, random: 0, mcts_fast: 1, Reward: 524.00, Loss: 0.0353, Epsilon: 0.0100
# Episode 1360/1500, Opponents: self: 6, random: 1, mcts_fast: 3, Reward: 260.00, Loss: 0.0485, Epsilon: 0.0100
# Episode 1370/1500, Opponents: self: 9, random: 0, mcts_fast: 1, Reward: 362.00, Loss: 0.0385, Epsilon: 0.0100
# Episode 1380/1500, Opponents: self: 8, random: 1, mcts_fast: 1, Reward: 382.00, Loss: 0.0377, Epsilon: 0.0100
# Episode 1390/1500, Opponents: self: 7, random: 1, mcts_fast: 2, Reward: 494.00, Loss: 0.0443, Epsilon: 0.0100
# Episode 1400/1500, Opponents: self: 7, random: 1, mcts_fast: 2, Reward: 296.00, Loss: 0.0361, Epsilon: 0.0100
# Episode 1410/1500, Opponents: self: 8, random: 2, mcts_fast: 0, Reward: 24.00, Loss: 0.0487, Epsilon: 0.0100
# Episode 1420/1500, Opponents: self: 7, random: 0, mcts_fast: 3, Reward: 276.00, Loss: 0.0431, Epsilon: 0.0100
# Episode 1430/1500, Opponents: self: 8, random: 1, mcts_fast: 1, Reward: 372.00, Loss: 0.0333, Epsilon: 0.0100
# Episode 1440/1500, Opponents: self: 7, random: 3, mcts_fast: 0, Reward: 503.00, Loss: 0.0365, Epsilon: 0.0100
# Episode 1450/1500, Opponents: self: 5, random: 2, mcts_fast: 3, Reward: 200.00, Loss: 0.0360, Epsilon: 0.0100
# Episode 1460/1500, Opponents: self: 8, random: 1, mcts_fast: 1, Reward: 436.00, Loss: 0.0295, Epsilon: 0.0100
# Episode 1470/1500, Opponents: self: 5, random: 1, mcts_fast: 4, Reward: 415.00, Loss: 0.0330, Epsilon: 0.0100
# Episode 1480/1500, Opponents: self: 6, random: 0, mcts_fast: 4, Reward: 150.00, Loss: 0.0355, Epsilon: 0.0100
# Episode 1490/1500, Opponents: self: 9, random: 0, mcts_fast: 1, Reward: 350.00, Loss: 0.0304, Epsilon: 0.0100
# Episode 1500/1500, Opponents: self: 9, random: 1, mcts_fast: 0, Reward: 315.00, Loss: 0.0314, Epsilon: 0.0100
# DQN agent training completed and model saved.

# %%
# Plot rewards and losses
plt.figure(figsize=(15, 6))

# Plot rewards
plt.subplot(1, 2, 1)
plt.plot(rewards, label='Reward', alpha=0.7)
plt.plot(np.convolve(rewards, np.ones(10)/10, mode='valid'), label='Moving Avg (10 episodes)', linewidth=2)
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('DQN Training Rewards')
plt.legend()
plt.grid(True)

# Plot losses
plt.subplot(1, 2, 2)
plt.plot(losses, label='Loss', alpha=0.7)
plt.plot(np.convolve(losses, np.ones(10)/10, mode='valid'), label='Moving Avg (10 episodes)', linewidth=2)
plt.xlabel('Episode')
plt.ylabel('Loss')
plt.title('DQN Training Losses')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Number of evaluation games
num_eval_games = 50

print("Evaluating agents...")

# Evaluate DQN vs Random
dqn_vs_random = evaluate_agent(dqn_agent, random_agent, num_games=num_eval_games)
random_vs_dqn = evaluate_agent(random_agent, dqn_agent, num_games=num_eval_games)

# Evaluate DQN vs MCTS
dqn_vs_mcts = evaluate_agent(dqn_agent, mcts_agent, num_games=num_eval_games)
mcts_vs_dqn = evaluate_agent(mcts_agent, dqn_agent, num_games=num_eval_games)

# Evaluate MCTS vs Random
mcts_vs_random = evaluate_agent(mcts_agent, random_agent, num_games=num_eval_games)
random_vs_mcts = evaluate_agent(random_agent, mcts_agent, num_games=num_eval_games)

# Evaluate DQN vs DQN and MCTS vs MCTS
dqn_vs_dqn = evaluate_agent(dqn_agent, dqn_agent, num_games=num_eval_games)
mcts_vs_mcts = evaluate_agent(mcts_agent, mcts_agent, num_games=num_eval_games)

# Evaluate Random vs Random
random_vs_random = evaluate_agent(random_agent, random_agent, num_games=num_eval_games*200)

# Print evaluation results
print("\nEvaluation Results:")
print(f"DQN (BLACK) vs Random (WHITE): Win Rate {dqn_vs_random['win_rate']:.2%}, Avg Reward {dqn_vs_random['avg_reward']:.2f}")
print(f"Random (BLACK) vs DQN (WHITE): Win Rate {random_vs_dqn['win_rate']:.2%}, Avg Reward {random_vs_dqn['avg_reward']:.2f}")
print(f"DQN (BLACK) vs MCTS (WHITE): Win Rate {dqn_vs_mcts['win_rate']:.2%}, Avg Reward {dqn_vs_mcts['avg_reward']:.2f}")
print(f"MCTS (BLACK) vs DQN (WHITE): Win Rate {mcts_vs_dqn['win_rate']:.2%}, Avg Reward {mcts_vs_dqn['avg_reward']:.2f}")
print(f"MCTS (BLACK) vs Random (WHITE): Win Rate {mcts_vs_random['win_rate']:.2%}, Avg Reward {mcts_vs_random['avg_reward']:.2f}")
print(f"Random (BLACK) vs MCTS (WHITE): Win Rate {random_vs_mcts['win_rate']:.2%}, Avg Reward {random_vs_mcts['avg_reward']:.2f}")
print(f"DQN (BLACK) vs DQN (WHITE): Win Rate {dqn_vs_dqn['win_rate']:.2%}, Avg Reward {dqn_vs_dqn['avg_reward']:.2f}")
print(f"MCTS (BLACK) vs MCTS (WHITE): Win Rate {mcts_vs_mcts['win_rate']:.2%}, Avg Reward {mcts_vs_mcts['avg_reward']:.2f}")
print(f"Random (BLACK) vs Random (WHITE): Win Rate {random_vs_random['win_rate']:.2%}, Avg Reward {random_vs_random['avg_reward']:.2f}")
# Out:
# Evaluating agents...
# DQN vs Random: 100%|██████████| 50/50 [00:05<00:00,  9.55it/s]
# Random vs DQN: 100%|██████████| 50/50 [00:05<00:00,  8.46it/s]
# DQN vs MCTS_99: 100%|██████████| 50/50 [23:06<00:00, 27.73s/it]
# MCTS_99 vs DQN: 100%|██████████| 50/50 [25:35<00:00, 30.71s/it]
# MCTS_99 vs Random: 100%|██████████| 50/50 [13:02<00:00, 15.64s/it]
# Random vs MCTS_99: 100%|██████████| 50/50 [11:00<00:00, 13.22s/it]
# Evaluation Results:
# DQN (BLACK) vs Random (WHITE): Win Rate 62.00%, Avg Reward 18.26
# Random (BLACK) vs DQN (WHITE): Win Rate 44.00%, Avg Reward 207.98
# DQN (BLACK) vs MCTS (WHITE): Win Rate 6.00%, Avg Reward 165.36
# MCTS (BLACK) vs DQN (WHITE): Win Rate 0.00%, Avg Reward -152.68
# MCTS (BLACK) vs Random (WHITE): Win Rate 56.00%, Avg Reward 72.34
# Random (BLACK) vs MCTS (WHITE): Win Rate 36.00%, Avg Reward 92.42

# %%
num_eval_games = 50

# Evaluate DQN vs DQN and MCTS vs MCTS
dqn_vs_dqn = evaluate_agent(dqn_agent, dqn_agent, num_games=num_eval_games)
mcts_vs_mcts = evaluate_agent(mcts_agent, mcts_agent, num_games=num_eval_games)

print(f"DQN (BLACK) vs DQN (WHITE): Win Rate {dqn_vs_dqn['win_rate']:.2%}, Avg Reward {dqn_vs_dqn['avg_reward']:.2f}")
print(f"MCTS (BLACK) vs MCTS (WHITE): Win Rate {mcts_vs_mcts['win_rate']:.2%}, Avg Reward {mcts_vs_mcts['avg_reward']:.2f}")
# Out:
# DQN vs DQN: 100%|██████████| 50/50 [00:04<00:00, 10.46it/s]
# MCTS_99 vs MCTS_99: 100%|██████████| 50/50 [17:57<00:00, 21.55s/it]
# DQN (BLACK) vs DQN (WHITE): Win Rate 20.00%, Avg Reward 67.14
# MCTS (BLACK) vs MCTS (WHITE): Win Rate 0.00%, Avg Reward -289.00

# %%
random_vs_random = evaluate_agent(random_agent, random_agent, num_games=10000)
print(f"Random (BLACK) vs Random (WHITE): Win Rate {random_vs_random['win_rate']:.2%}, Avg Reward {random_vs_random['avg_reward']:.2f}")
# Out:
# Random vs Random: 100%|██████████| 10000/10000 [05:48<00:00, 28.73it/s]
# Random (BLACK) vs Random (WHITE): Win Rate 45.18%, Avg Reward 98.70

# %%
# Create dictionaries to store results by starting color
black_results = {
    'DQN vs Random': dqn_vs_random,
    'DQN vs MCTS': dqn_vs_mcts,
    'MCTS vs Random': mcts_vs_random
}

white_results = {
    'Random vs DQN': random_vs_dqn,
    'MCTS vs DQN': mcts_vs_dqn,
    'Random vs MCTS': random_vs_mcts
}

# Create matchup pairs for analysis
matchup_pairs = [
    ('DQN vs Random', 'Random vs DQN'),
    ('DQN vs MCTS', 'MCTS vs DQN'),
    ('MCTS vs Random', 'Random vs MCTS')
]

# Plot win rates by starting color
plt.figure(figsize=(12, 6))

# Create lists for plotting
matchups = [pair[0] for pair in matchup_pairs]
black_win_rates = [black_results[pair[0]]['win_rate'] for pair in matchup_pairs]
white_win_rates = [1 - white_results[pair[1]]['win_rate'] for pair in matchup_pairs]  # Invert for same perspective

# Bar positions
x = np.arange(len(matchups))
width = 0.35

# Plot bars
plt.bar(x - width/2, black_win_rates, width, label='Starting as BLACK')
plt.bar(x + width/2, white_win_rates, width, label='Starting as WHITE')

# Add labels and title
plt.xlabel('Matchup')
plt.ylabel('Win Rate')
plt.title('Win Rates by Starting Color')
plt.xticks(x, matchups)
plt.legend()
plt.grid(True, axis='y')

# Add value labels
for i, v in enumerate(black_win_rates):
    plt.text(i - width/2, v + 0.02, f'{v:.2%}', ha='center')
for i, v in enumerate(white_win_rates):
    plt.text(i + width/2, v + 0.02, f'{v:.2%}', ha='center')

plt.tight_layout()
plt.show()

# Calculate color advantage
print("\nStarting Color Advantage Analysis:")
for (black_matchup, white_matchup) in matchup_pairs:
    black_win = black_results[black_matchup]['win_rate']
    white_win = 1 - white_results[white_matchup]['win_rate']  # Invert to get same perspective
    advantage = black_win - white_win
    print(f"{black_matchup}: BLACK advantage = {advantage:.2%}")
# Out:
# Starting Color Advantage Analysis:
# DQN vs Random: BLACK advantage = 6.00%
# DQN vs MCTS: BLACK advantage = -94.00%
# MCTS vs Random: BLACK advantage = -8.00%

# %%
# Create a structured dataset from evaluation results
results = {
    "Agent": [
        "DQN vs Random", "Random vs DQN", 
        "DQN vs MCTS", "MCTS vs DQN",
        "MCTS vs Random", "Random vs MCTS"
    ],
    "Wins": [
        dqn_vs_random['wins'], random_vs_dqn['wins'],
        dqn_vs_mcts['wins'], mcts_vs_dqn['wins'],
        mcts_vs_random['wins'], random_vs_mcts['wins']
    ],
    "Losses": [
        dqn_vs_random['losses'], random_vs_dqn['losses'],
        dqn_vs_mcts['losses'], mcts_vs_dqn['losses'],
        mcts_vs_random['losses'], random_vs_mcts['losses']
    ],
    "Draws": [
        dqn_vs_random['draws'], random_vs_dqn['draws'],
        dqn_vs_mcts['draws'], mcts_vs_dqn['draws'],
        mcts_vs_random['draws'], random_vs_mcts['draws']
    ]
}

# Visualization of game outcome distribution (wins, losses, draws)
plt.figure(figsize=(12, 6))

# Prepare data
agents = results["Agent"]
wins = results["Wins"]
losses = results["Losses"]
draws = results["Draws"]

x = np.arange(len(agents))  # Bar group positions
width = 0.25  # Bar width

# Create bars
plt.bar(x - width, wins, width, label='Wins', color='green')
plt.bar(x, losses, width, label='Losses', color='red')
plt.bar(x + width, draws, width, label='Draws', color='gray')

# Add labels and legends
plt.xlabel('Matchups')
plt.ylabel('Number of Games')
plt.title('Game Outcome Distribution by Agent Matchup')
plt.xticks(x, agents, rotation=45, ha='right')
plt.legend()

# Add values on bars
for i, v in enumerate(wins):
    plt.text(i - width, v + 0.5, str(v), ha='center', va='bottom')
for i, v in enumerate(losses):
    plt.text(i, v + 0.5, str(v), ha='center', va='bottom')
for i, v in enumerate(draws):
    plt.text(i + width, v + 0.5, str(v), ha='center', va='bottom')

plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.show()

# %%
# Function to measure agent decision time
def measure_decision_time(agent, num_decisions=100):
    env = OthelloEnv()
    total_time = 0
    decisions = 0
    
    for _ in tqdm(range(num_decisions), desc=f"Measuring {agent.name} performance"):
        # Reset the environment occasionally to get various board states
        if decisions % 10 == 0:
            obs, _ = env.reset()
            
        # Skip if no valid moves
        valid_moves = [i for i, is_valid in enumerate(obs["valid_moves"]) if is_valid == 1]
        if not valid_moves:
            continue
        
        # Measure time to choose an action
        start_time = time.time()
        action = agent.choose_action(env)
        end_time = time.time()
        
        # Record time
        decision_time = end_time - start_time
        total_time += decision_time
        decisions += 1
        
        # Execute the action to advance the game
        obs, _, terminated, truncated, _ = env.step(action)
        
        # Reset if the game ended
        if terminated or truncated:
            obs, _ = env.reset()
    
    # Calculate average time
    avg_time = total_time / decisions if decisions > 0 else 0
    return avg_time

# Measure decision time for each agent
print("Measuring agent decision times...")
random_time = measure_decision_time(random_agent, num_decisions=100)
mcts_fast_time = measure_decision_time(mcts_agent_fast, num_decisions=50)
mcts_time = measure_decision_time(mcts_agent, num_decisions=20)
mcts_deep_time = measure_decision_time(mcts_agent_deep, num_decisions=10)
dqn_time = measure_decision_time(dqn_agent, num_decisions=100)

# Plot decision times
plt.figure(figsize=(10, 6))
agents = ['Random', 'MCTS (50)', 'MCTS (100)', 'MCTS (200)', 'DQN']
times = [random_time, mcts_fast_time, mcts_time, mcts_deep_time, dqn_time]

bars = plt.bar(agents, times, color=['gray', 'lightblue', 'blue', 'darkblue', 'green'])
plt.xlabel('Agent')
plt.ylabel('Average Decision Time (seconds)')
plt.title('Agent Decision Time Comparison')
plt.grid(True, axis='y')

# Add value labels
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height + 0.01,
             f'{height:.4f}s', ha='center')

plt.tight_layout()
plt.show()

# Print decision times
print("\nAgent Decision Times:")
print(f"Random Agent: {random_time:.4f} seconds")
print(f"MCTS (50 simulations): {mcts_fast_time:.4f} seconds")
print(f"MCTS (100 simulations): {mcts_time:.4f} seconds")
print(f"MCTS (200 simulations): {mcts_deep_time:.4f} seconds")
print(f"DQN Agent: {dqn_time:.4f} seconds")

# Calculate MCTS scaling efficiency
print("\nMCTS Scaling Efficiency:")
print(f"100/50 sims ratio: {mcts_time/mcts_fast_time:.2f}x time for {100/50:.2f}x simulations")
print(f"200/100 sims ratio: {mcts_deep_time/mcts_time:.2f}x time for {200/100:.2f}x simulations")
# Out:
# Measuring agent decision times...
# Measuring Random performance: 100%|██████████| 100/100 [00:00<00:00, 992.45it/s]
# Measuring MCTS_44 performance: 100%|██████████| 50/50 [00:20<00:00,  2.47it/s]
# Measuring MCTS_99 performance: 100%|██████████| 20/20 [00:18<00:00,  1.11it/s]
# Measuring MCTS_198 performance: 100%|██████████| 10/10 [00:18<00:00,  1.80s/it]
# Measuring DQN performance: 100%|██████████| 100/100 [00:00<00:00, 508.46it/s]
# Agent Decision Times:
# Random Agent: 0.0001 seconds
# MCTS (50 simulations): 0.4025 seconds
# MCTS (100 simulations): 0.9017 seconds
# MCTS (200 simulations): 1.8014 seconds
# DQN Agent: 0.0010 seconds
#
# MCTS Scaling Efficiency:
# 100/50 sims ratio: 2.24x time for 2.00x simulations
# 200/100 sims ratio: 2.00x time for 2.00x simulations

# %%
# Create comparative measures of agent strength vs computational cost
agent_names = ['Random', 'MCTS (50)', 'MCTS (100)', 'MCTS (200)', 'DQN']

# Define computational cost (decision time) and win rates
# We'll use the time measurements above
decision_times = [random_time, mcts_fast_time, mcts_time, mcts_deep_time, dqn_time]

# Approximate win rates against random agent (based on evaluation)
# These values should be replaced with actual results from your evaluation
win_rates_vs_random = [
    0.50,  # Random vs Random is 50%
    mcts_vs_random['win_rate'],  # MCTS (fast) vs Random
    mcts_vs_random['win_rate'] + 0.05,  # MCTS (500) vs Random 
    mcts_vs_random['win_rate'] + 0.08,  # MCTS (1000) vs Random
    dqn_vs_random['win_rate']   # DQN vs Random
]

# Calculate efficiency (win rate / decision time) excluding the random agent
efficiency = [win_rate / time for win_rate, time in zip(win_rates_vs_random[1:], decision_times[1:])]
efficiency_agent_names = agent_names[1:]

# Plot the data
plt.figure(figsize=(15, 6))

# Win rate vs decision time
plt.subplot(1, 2, 1)
plt.scatter(decision_times, win_rates_vs_random, s=100, alpha=0.7)
for i, name in enumerate(agent_names):
    plt.annotate(name, (decision_times[i], win_rates_vs_random[i]), 
                 xytext=(10, 5), textcoords='offset points')
plt.xlabel('Decision Time (seconds)')
plt.ylabel('Win Rate vs Random Agent')
plt.title('Agent Performance vs Computational Cost')
plt.grid(True)

# Efficiency
plt.subplot(1, 2, 2)
plt.bar(efficiency_agent_names, efficiency)
plt.xlabel('Agent')
plt.ylabel('Efficiency (Win Rate / Decision Time)')
plt.title('Agent Efficiency')
plt.xticks(rotation=45)
plt.grid(True, axis='y')

plt.tight_layout()
plt.show()

# Analyze results
best_agent_idx = np.argmax(win_rates_vs_random)
most_efficient_idx = np.argmax(efficiency)

print(f"Strongest agent against Random: {agent_names[best_agent_idx]} (Win rate: {win_rates_vs_random[best_agent_idx]:.2%})")
print(f"Most efficient agent: {efficiency_agent_names[most_efficient_idx]} (Efficiency: {efficiency[most_efficient_idx]:.4f})")
# Out:
# Strongest agent against Random: MCTS (200) (Win rate: 64.00%)
# Most efficient agent: DQN (Efficiency: 601.0448)

# %%
# Visualize a game between the best agents
print("Visualizing a game between DQN and MCTS...")
visualize_game(mcts_agent, dqn_agent, delay=0.5)
# Out:
# Visualizing a game between DQN and MCTS...
# White (DQN) won! 50-14
